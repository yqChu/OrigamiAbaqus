# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.loadtxt(f"C:/Research/Nonreciprocity/OrigamiAbaqus/PostProcess/Expr-2-3-Static/LeftLoad=5.txt",skiprows=3)
Force = data[:,1]
Time = data[:,0]

data = np.loadtxt(f"C:/Research/Nonreciprocity/OrigamiAbaqus/PostProcess/Expr-2-3-Static/LeftStaticNlgeomLoad=5.txt",skiprows=3)
Disp = data[:,1]
Time = data[:,0]

plt.figure(figsize=(8,6))
plt.plot(-Force, -Disp, label="Load at Left")

data = np.loadtxt(f"C:/Research/Nonreciprocity/OrigamiAbaqus/PostProcess/Expr-2-3-Static/RightLoad=5.txt",skiprows=3)
Force = data[:,1]
Time = data[:,0]

data = np.loadtxt(f"C:/Research/Nonreciprocity/OrigamiAbaqus/PostProcess/Expr-2-3-Static/RightStaticNlgeomLoad=5.txt",skiprows=3)
Disp = data[:,1]
Time = data[:,0]

plt.plot(Force, Disp, label = "Load at Right")
plt.legend()
plt.grid(True)
plt.xlabel("Force(N)")
plt.ylabel("Displacment(m)")
# Out:
# Text(0, 0.5, 'Displacment(m)')

# %%
L = 7*0.016*np.cos(np.pi/16)

data = np.loadtxt(f"C:/Research/Nonreciprocity/OrigamiAbaqus/PostProcess/Expr-2-3-Static/LeftF+Force.txt",skiprows=3)
Force = data[:,1]
Time = data[:,0]
data = np.loadtxt(f"C:/Research/Nonreciprocity/OrigamiAbaqus/PostProcess/Expr-2-3-Static/LeftF+Disp.txt",skiprows=3)
Disp = data[:,1]
Time = data[:,0]
plt.figure(figsize=(8,6))
plt.plot(-Force, -Disp/L, 'r', label="Load at Left")

data = np.loadtxt(f"C:/Research/Nonreciprocity/OrigamiAbaqus/PostProcess/Expr-2-3-Static/LeftF-Force.txt",skiprows=3)
Force = data[:,1]
Time = data[:,0]
data = np.loadtxt(f"C:/Research/Nonreciprocity/OrigamiAbaqus/PostProcess/Expr-2-3-Static/LeftF-Disp.txt",skiprows=3)
Disp = data[:,1]
Time = data[:,0]
plt.plot(-Force, -Disp/L, 'r')

data = np.loadtxt(f"C:/Research/Nonreciprocity/OrigamiAbaqus/PostProcess/Expr-2-3-Static/RightF+Force.txt",skiprows=3)
Force = data[:,1]
Time = data[:,0]
data = np.loadtxt(f"C:/Research/Nonreciprocity/OrigamiAbaqus/PostProcess/Expr-2-3-Static/RightF+Disp.txt",skiprows=3)
Disp = data[:,1]
Time = data[:,0]
plt.plot(Force, Disp/L, 'b', label="Load at Right")

data = np.loadtxt(f"C:/Research/Nonreciprocity/OrigamiAbaqus/PostProcess/Expr-2-3-Static/RightF-Force.txt",skiprows=3)
Force = data[:,1]
Time = data[:,0]
data = np.loadtxt(f"C:/Research/Nonreciprocity/OrigamiAbaqus/PostProcess/Expr-2-3-Static/RightF-Disp.txt",skiprows=3)
Disp = data[:,1]
Time = data[:,0]
plt.plot(Force, Disp/L, 'b')

plt.legend()
plt.grid(True)
plt.xlabel("F(N)")
plt.ylabel(r'$\frac{u}{L}$')
# Out:
# Text(0, 0.5, '$\\frac{u}{L}$')
