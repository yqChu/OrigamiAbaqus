# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Displacement and Velocity

peak_disp_mag = np.zeros((10, 2))
peak_vel_mag = np.zeros((10, 2))
index = 0

for amp_id in range(10):
    plt.figure(figsize=(8,3))
    for load_type in ["Left", "Right"]:
        for data_type in ["Disp", "Vel"]:
            data = np.loadtxt(f"C:/Research/Nonreciprocity/OrigamiAbaqus/PostProcess/Expr-2-3-f=200-AmplitudeSweeping/{load_type}Load{data_type}Freq=200Amp={amp_id+1}hor_num=4.txt",skiprows=3)
            time = data[:,0]
            disp = data[:,1]
            magnitudes = np.fft.fft(disp)
            frequencies = np.fft.fftfreq(len(disp), 
            (time[-1]-time[0])/len(time))
            if data_type=="Disp":
                plt.subplot(1,2,1)
            else:
                plt.subplot(1,2,2)
            if load_type=="Left":
                plt.plot(frequencies*2*np.pi, abs(magnitudes), 'r', label=f"{load_type}, {data_type}")
            else:
                plt.plot(frequencies*2*np.pi, abs(magnitudes), 'b', label=f"{load_type}, {data_type}")
            plt.title(f"Amplitude={amp_id+1}")
            plt.grid(True)
            plt.xlim(0,500)
            plt.legend(loc='upper right')

            w_min = 0
            w_max = 500
            indices = np.where((frequencies>=w_min) & (frequencies*2*np.pi<=w_max))[0]
            selected_freqs = frequencies[indices]
            selected_mags = magnitudes[indices]
            peak_idx = np.argmax(abs(selected_mags))
            peak_freq = selected_freqs[peak_idx]
            if load_type=="Left":
                if data_type=="Disp":
                    peak_disp_mag[index,0] = abs(selected_mags[peak_idx])
                else:
                    peak_vel_mag[index,0] = abs(selected_mags[peak_idx])
            else:
                if data_type=="Disp":
                    peak_disp_mag[index,1] = abs(selected_mags[peak_idx])
                else:
                    peak_vel_mag[index,1] = abs(selected_mags[peak_idx])
    index += 1

# %%
peak_force_mag = np.zeros((10, 2))
data_type="Force"
index = 0
plt.figure(figsize=(20,6))

for amp_id in range(1,11):
    for load_type in ["Left"]:
        data = np.loadtxt(f"C:/Research/Nonreciprocity/OrigamiAbaqus/PostProcess/Expr-2-3-f=200-AmplitudeSweeping/{load_type}Load{data_type}Freq=200Amp={amp_id}hor_num=3.txt",skiprows=3)
        time = data[:,0]
        disp = data[:,1]
        magnitudes = np.fft.fft(disp)
        frequencies = np.fft.fftfreq(len(disp), (time[-1]-time[0])/len(time))
        plt.subplot(2,5,index+1)
        if load_type=="Left":
            plt.plot(frequencies*2*np.pi, abs(magnitudes), 'r', label=f"{load_type}, {data_type}")
        else:
            plt.plot(frequencies*2*np.pi, abs(magnitudes), 'b', label=f"{load_type}, {data_type}")
        plt.title(f"Amplitude={amp_id}")
        plt.grid(True)
        plt.xlim(0,500)
        plt.legend(loc='upper right')
        w_min = 0
        w_max = 500
        indices = np.where((frequencies>=w_min) & (frequencies*2*np.pi<=w_max))[0]
        selected_freqs = frequencies[indices]
        selected_mags = magnitudes[indices]
        peak_idx = np.argmax(abs(selected_mags))
        peak_freq = selected_freqs[peak_idx]
        if load_type=="Left":
            peak_force_mag[index,0] = abs(selected_mags[peak_idx])
        else:
            peak_force_mag[index,1] = abs(selected_mags[peak_idx])
    index += 1
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 8
#       6 for amp_id in range(1,11):
#       7     for load_type in ["Left"]:
# ----> 8         data = np.loadtxt(f"C:/Research/Nonreciprocity/OrigamiAbaqus/PostProcess/Expr-2-3-f=200-AmplitudeSweeping/{load_type}Load{data_type}Freq=200Amp={amp_id}hor_num=3.txt",skiprows=3)
#       9         time = data[:,0]
#      10         disp = data[:,1]
#
# File c:\anaconda\envs\abq_env\Lib\site-packages\numpy\lib\npyio.py:1373, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1370 if isinstance(delimiter, bytes):
#    1371     delimiter = delimiter.decode('latin1')
# -> 1373 arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
#    1374             converters=converters, skiplines=skiprows, usecols=usecols,
#    1375             unpack=unpack, ndmin=ndmin, encoding=encoding,
#    1376             max_rows=max_rows, quote=quotechar)
#    1378 return arr
#
# File c:\anaconda\envs\abq_env\Lib\site-packages\numpy\lib\npyio.py:992, in _read(fname, delimiter, comment, quote, imaginary_unit, usecols, skiplines, max_rows, converters, ndmin, unpack, dtype, encoding)
#     990     fname = os.fspath(fname)
#     991 if isinstance(fname, str):
# --> 992     fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#     993     if encoding is None:
#     994         encoding = getattr(fh, 'encoding', 'latin1')
#
# File c:\anaconda\envs\abq_env\Lib\site-packages\numpy\lib\_datasource.py:193, in open(path, mode, destpath, encoding, newline)
#     156 """
#     157 Open `path` with `mode` and return the file object.
#     158
#    (...)
#     189
#     190 """
#     192 ds = DataSource(destpath)
# --> 193 return ds.open(path, mode, encoding=encoding, newline=newline)
#
# File c:\anaconda\envs\abq_env\Lib\site-packages\numpy\lib\_datasource.py:533, in DataSource.open(self, path, mode, encoding, newline)
#     530     return _file_openers[ext](found, mode=mode,
#     531                               encoding=encoding, newline=newline)
#     532 else:
# --> 533     raise FileNotFoundError(f"{path} not found.")
#
# FileNotFoundError: C:/Research/Nonreciprocity/OrigamiAbaqus/PostProcess/Expr-2-3-f=200-AmplitudeSweeping/LeftLoadForceFreq=200Amp=1hor_num=3.txt not found.

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.scatter(range(1,11), peak_disp_mag[:,0], c='r', s=20, label="LeftLoad")
plt.scatter(range(1,11), peak_disp_mag[:,1], c='b', s=20, label="RightLoad")
plt.grid(True)
plt.title("Displacement FFT Magnitude -- Shaking Amplitude")
plt.xlabel("Amplitude")
plt.ylabel("Magnitude")
plt.legend(loc="lower right")

plt.subplot(1,2,2)
plt.scatter(range(1,11), peak_vel_mag[:,0], c='r', s=20, label="LeftLoad")
plt.scatter(range(1,11), peak_vel_mag[:,1], c='b', s=20, label="RightLoad")
plt.grid(True)
plt.title("Velocity FFT Magnitude -- Shaking Amplitude")
plt.xlabel("Amplitude")
plt.ylabel("Magnitude")
plt.legend(loc="lower right")

# %%
# hor_num=5

peak_disp_mag = np.zeros((10, 2))
peak_vel_mag = np.zeros((10, 2))
index = 0

for amp_id in range(10):
    plt.figure(figsize=(8,3))
    for load_type in ["Left", "Right"]:
        for data_type in ["Disp", "Vel"]:
            data = np.loadtxt(f"C:/Research/Nonreciprocity/OrigamiAbaqus/PostProcess/Expr-2-3-f=200-AmplitudeSweeping/{load_type}Load{data_type}Freq=200Amp={amp_id+1}hor_num=5.txt",skiprows=3)
            time = data[:,0]
            disp = data[:,1]
            magnitudes = np.fft.fft(disp)
            frequencies = np.fft.fftfreq(len(disp), 
            (time[-1]-time[0])/len(time))
            if data_type=="Disp":
                plt.subplot(1,2,1)
            else:
                plt.subplot(1,2,2)
            if load_type=="Left":
                plt.plot(frequencies*2*np.pi, abs(magnitudes), 'r', label=f"{load_type}, {data_type}")
            else:
                plt.plot(frequencies*2*np.pi, abs(magnitudes), 'b', label=f"{load_type}, {data_type}")
            plt.title(f"Amplitude={amp_id+1}")
            plt.grid(True)
            plt.xlim(0,500)
            plt.legend(loc='upper right')

            w_min = 0
            w_max = 500
            indices = np.where((frequencies>=w_min) & (frequencies*2*np.pi<=w_max))[0]
            selected_freqs = frequencies[indices]
            selected_mags = magnitudes[indices]
            peak_idx = np.argmax(abs(selected_mags))
            peak_freq = selected_freqs[peak_idx]
            if load_type=="Left":
                if data_type=="Disp":
                    peak_disp_mag[index,0] = abs(selected_mags[peak_idx])
                else:
                    peak_vel_mag[index,0] = abs(selected_mags[peak_idx])
            else:
                if data_type=="Disp":
                    peak_disp_mag[index,1] = abs(selected_mags[peak_idx])
                else:
                    peak_vel_mag[index,1] = abs(selected_mags[peak_idx])
    index += 1

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.scatter(range(1,11), peak_disp_mag[:,0], c='r', s=20, label="LeftLoad")
plt.scatter(range(1,11), peak_disp_mag[:,1], c='b', s=20, label="RightLoad")
plt.grid(True)
plt.title("Displacement FFT Magnitude -- Shaking Amplitude")
plt.xlabel("Amplitude")
plt.ylabel("Magnitude")
plt.legend(loc="lower right")

plt.subplot(1,2,2)
plt.scatter(range(1,11), peak_vel_mag[:,0], c='r', s=20, label="LeftLoad")
plt.scatter(range(1,11), peak_vel_mag[:,1], c='b', s=20, label="RightLoad")
plt.grid(True)
plt.title("Velocity FFT Magnitude -- Shaking Amplitude")
plt.xlabel("Amplitude")
plt.ylabel("Magnitude")
plt.legend(loc="lower right")

# %%
# hor_num=3 version 2, adjust the stiffness of rotational spring

peak_disp_mag = np.zeros((10, 2))
peak_vel_mag = np.zeros((10, 2))
index = 0

for amp_id in range(10):
    plt.figure(figsize=(8,3))
    for load_type in ["Left", "Right"]:
        for data_type in ["Disp", "Vel"]:
            data = np.loadtxt(f"C:/Research/Nonreciprocity/OrigamiAbaqus/PostProcess/Expr-2-3-f=200-AmplitudeSweeping/{load_type}Load{data_type}Freq=200Amp={amp_id+1}hor_num=3v2.txt",skiprows=3)
            time = data[:,0]
            disp = data[:,1]
            magnitudes = np.fft.fft(disp)
            frequencies = np.fft.fftfreq(len(disp), 
            (time[-1]-time[0])/len(time))
            if data_type=="Disp":
                plt.subplot(1,2,1)
            else:
                plt.subplot(1,2,2)
            if load_type=="Left":
                plt.plot(frequencies*2*np.pi, abs(magnitudes), 'r', label=f"{load_type}, {data_type}")
            else:
                plt.plot(frequencies*2*np.pi, abs(magnitudes), 'b', label=f"{load_type}, {data_type}")
            plt.title(f"Amplitude={amp_id+1}")
            plt.grid(True)
            plt.xlim(0,500)
            plt.legend(loc='upper right')

            w_min = 0
            w_max = 500
            indices = np.where((frequencies>=w_min) & (frequencies*2*np.pi<=w_max))[0]
            selected_freqs = frequencies[indices]
            selected_mags = magnitudes[indices]
            peak_idx = np.argmax(abs(selected_mags))
            peak_freq = selected_freqs[peak_idx]
            if load_type=="Left":
                if data_type=="Disp":
                    peak_disp_mag[index,0] = abs(selected_mags[peak_idx])
                else:
                    peak_vel_mag[index,0] = abs(selected_mags[peak_idx])
            else:
                if data_type=="Disp":
                    peak_disp_mag[index,1] = abs(selected_mags[peak_idx])
                else:
                    peak_vel_mag[index,1] = abs(selected_mags[peak_idx])
    index += 1

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.scatter(range(1,11), peak_disp_mag[:,0], c='r', s=20, label="LeftLoad")
plt.scatter(range(1,11), peak_disp_mag[:,1], c='b', s=20, label="RightLoad")
plt.grid(True)
plt.title("Displacement FFT Magnitude -- Shaking Amplitude")
plt.xlabel("Amplitude")
plt.ylabel("Magnitude")
plt.legend(loc="lower right")

plt.subplot(1,2,2)
plt.scatter(range(1,11), peak_vel_mag[:,0], c='r', s=20, label="LeftLoad")
plt.scatter(range(1,11), peak_vel_mag[:,1], c='b', s=20, label="RightLoad")
plt.grid(True)
plt.title("Velocity FFT Magnitude -- Shaking Amplitude")
plt.xlabel("Amplitude")
plt.ylabel("Magnitude")
plt.legend(loc="lower right")

# %%
# hor_num=7

peak_disp_mag = np.zeros((10, 2))
peak_vel_mag = np.zeros((10, 2))
index = 0

for amp_id in range(10):
    plt.figure(figsize=(8,3))
    for load_type in ["Left", "Right"]:
        for data_type in ["Disp", "Vel"]:
            data = np.loadtxt(f"C:/Research/Nonreciprocity/OrigamiAbaqus/PostProcess/Expr-2-3-f=200-AmplitudeSweeping/{load_type}Load{data_type}Freq=200Amp={amp_id+1}hor_num=7.txt",skiprows=3)
            time = data[:,0]
            disp = data[:,1]
            magnitudes = np.fft.fft(disp)
            frequencies = np.fft.fftfreq(len(disp), 
            (time[-1]-time[0])/len(time))
            if data_type=="Disp":
                plt.subplot(1,2,1)
            else:
                plt.subplot(1,2,2)
            if load_type=="Left":
                plt.plot(frequencies*2*np.pi, abs(magnitudes), 'r', label=f"{load_type}, {data_type}")
            else:
                plt.plot(frequencies*2*np.pi, abs(magnitudes), 'b', label=f"{load_type}, {data_type}")
            plt.title(f"Amplitude={amp_id+1}")
            plt.grid(True)
            plt.xlim(0,500)
            plt.legend(loc='upper right')

            w_min = 0
            w_max = 500
            indices = np.where((frequencies>=w_min) & (frequencies*2*np.pi<=w_max))[0]
            selected_freqs = frequencies[indices]
            selected_mags = magnitudes[indices]
            peak_idx = np.argmax(abs(selected_mags))
            peak_freq = selected_freqs[peak_idx]
            if load_type=="Left":
                if data_type=="Disp":
                    peak_disp_mag[index,0] = abs(selected_mags[peak_idx])
                else:
                    peak_vel_mag[index,0] = abs(selected_mags[peak_idx])
            else:
                if data_type=="Disp":
                    peak_disp_mag[index,1] = abs(selected_mags[peak_idx])
                else:
                    peak_vel_mag[index,1] = abs(selected_mags[peak_idx])
    index += 1

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.scatter(range(1,11), peak_disp_mag[:,0], c='r', s=20, label="LeftLoad")
plt.scatter(range(1,11), peak_disp_mag[:,1], c='b', s=20, label="RightLoad")
plt.grid(True)
plt.title("Displacement FFT Magnitude -- Shaking Amplitude")
plt.xlabel("Amplitude")
plt.ylabel("Magnitude")
plt.legend(loc="lower right")

plt.subplot(1,2,2)
plt.scatter(range(1,11), peak_vel_mag[:,0], c='r', s=20, label="LeftLoad")
plt.scatter(range(1,11), peak_vel_mag[:,1], c='b', s=20, label="RightLoad")
plt.grid(True)
plt.title("Velocity FFT Magnitude -- Shaking Amplitude")
plt.xlabel("Amplitude")
plt.ylabel("Magnitude")
plt.legend(loc="lower right")
