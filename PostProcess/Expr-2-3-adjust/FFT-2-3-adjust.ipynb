# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Load 1 Left U2-1
# Sinusoidal force loading on the left, report the y direction displacement of the 1st (all 6) left loading node.

# %%
data = np.loadtxt('C:/Research/Nonreciprocity/OrigamiAbaqus/PostProcess/Expr-2-3-adjust/Load1LeftU2-1.txt',skiprows=3)
Load1LeftU2_1 = data[:,1]
T = data[:,0]

fft_result = np.fft.fft(Load1LeftU2_1)
frequencies = np.fft.fftfreq(len(Load1LeftU2_1), (T[-1]-T[0])/len(T))*2*np.pi

plt.figure(figsize=(16,8))

plt.subplot(2,2,1)
plt.plot(T, Load1LeftU2_1)
plt.grid(True)

plt.subplot(2,2,2)
plt.plot(frequencies, abs(fft_result))
plt.grid(True)
plt.xlim(0, 600)

data = np.loadtxt('C:/Research/Nonreciprocity/OrigamiAbaqus/PostProcess/Expr-2-3-adjust/Load1LeftV2-1.txt',skiprows=3)
Load1LeftV2_1 = data[:,1]
T = data[:,0]

fft_result = np.fft.fft(Load1LeftV2_1)
frequencies = np.fft.fftfreq(len(Load1LeftU2_1), (T[-1]-T[0])/len(T))*2*np.pi

plt.subplot(2,2,3)
plt.plot(T, Load1LeftV2_1)
plt.grid(True)

plt.subplot(2,2,4)
plt.plot(frequencies, abs(fft_result))
plt.grid(True)
plt.xlim(0, 600)
# Out:
# (0.0, 600.0)

# %% [markdown]
# # Load 1 Right U2-1
# Sinusoidal force loading on the left, report the y direction displacement of the 1st (all 6) right loading node.

# %%
data = np.loadtxt('C:/Research/Nonreciprocity/OrigamiAbaqus/PostProcess/Expr-2-3-adjust/Load1RightU2-1.txt',skiprows=3)
Load1LeftU2_1 = data[:,1]
T = data[:,0]

fft_result = np.fft.fft(Load1LeftU2_1)
frequencies = np.fft.fftfreq(len(Load1LeftU2_1), (T[-1]-T[0])/len(T))*2*np.pi

plt.figure(figsize=(16,8))

plt.subplot(2,2,1)
plt.plot(T, Load1LeftU2_1)
plt.grid(True)

plt.subplot(2,2,2)
plt.plot(frequencies, abs(fft_result))
plt.grid(True)
plt.xlim(0, 600)

data = np.loadtxt('C:/Research/Nonreciprocity/OrigamiAbaqus/PostProcess/Expr-2-3-adjust/Load1RightV2-1.txt',skiprows=3)
Load1LeftV2_1 = data[:,1]
T = data[:,0]

fft_result = np.fft.fft(Load1LeftV2_1)
frequencies = np.fft.fftfreq(len(Load1LeftU2_1), (T[-1]-T[0])/len(T))*2*np.pi

plt.subplot(2,2,3)
plt.plot(T, Load1LeftV2_1)
plt.grid(True)

plt.subplot(2,2,4)
plt.plot(frequencies, abs(fft_result))
plt.grid(True)
plt.xlim(0, 600)
# Out:
# (0.0, 600.0)

# %% [markdown]
# # Load 2 Left U2-1
# Sinusoidal force loading on the right, report the y direction displacement of the 1st (all 6) left loading node.

# %%
data = np.loadtxt('C:/Research/Nonreciprocity/OrigamiAbaqus/PostProcess/Expr-2-3-adjust/Load2LeftU2-1.txt',skiprows=3)
Load1LeftU2_1 = data[:,1]
T = data[:,0]

fft_result = np.fft.fft(Load1LeftU2_1)
frequencies = np.fft.fftfreq(len(Load1LeftU2_1), (T[-1]-T[0])/len(T))*2*np.pi

plt.figure(figsize=(16,8))

plt.subplot(2,2,1)
plt.plot(T, Load1LeftU2_1)
plt.grid(True)

plt.subplot(2,2,2)
plt.plot(frequencies, abs(fft_result))
plt.grid(True)
plt.xlim(0, 600)

data = np.loadtxt('C:/Research/Nonreciprocity/OrigamiAbaqus/PostProcess/Expr-2-3-adjust/Load2LeftV2-1.txt',skiprows=3)
Load1LeftV2_1 = data[:,1]
T = data[:,0]

fft_result = np.fft.fft(Load1LeftV2_1)
frequencies = np.fft.fftfreq(len(Load1LeftU2_1), (T[-1]-T[0])/len(T))*2*np.pi

plt.subplot(2,2,3)
plt.plot(T, Load1LeftV2_1)
plt.grid(True)

plt.subplot(2,2,4)
plt.plot(frequencies, abs(fft_result))
plt.grid(True)
plt.xlim(0, 600)
# Out:
# (0.0, 600.0)

# %% [markdown]
# # Load 2 Right U2-1
# Sinusoidal force loading on the right, report the y direction displacement of the 1st (all 6) left loading node.

# %%
data = np.loadtxt('C:/Research/Nonreciprocity/OrigamiAbaqus/PostProcess/Expr-2-3-adjust/Load2RightU2-1.txt',skiprows=3)
Load1LeftU2_1 = data[:,1]
T = data[:,0]

fft_result = np.fft.fft(Load1LeftU2_1)
frequencies = np.fft.fftfreq(len(Load1LeftU2_1), (T[-1]-T[0])/len(T))*2*np.pi

plt.figure(figsize=(16,8))

plt.subplot(2,2,1)
plt.plot(T, Load1LeftU2_1)
plt.grid(True)

plt.subplot(2,2,2)
plt.plot(frequencies, abs(fft_result))
plt.grid(True)
plt.xlim(0, 600)

data = np.loadtxt('C:/Research/Nonreciprocity/OrigamiAbaqus/PostProcess/Expr-2-3-adjust/Load2RightV2-1.txt',skiprows=3)
Load1LeftV2_1 = data[:,1]
T = data[:,0]

fft_result = np.fft.fft(Load1LeftV2_1)
frequencies = np.fft.fftfreq(len(Load1LeftU2_1), (T[-1]-T[0])/len(T))*2*np.pi

plt.subplot(2,2,3)
plt.plot(T, Load1LeftV2_1)
plt.grid(True)

plt.subplot(2,2,4)
plt.plot(frequencies, abs(fft_result))
plt.grid(True)
plt.xlim(0, 600)
# Out:
# (0.0, 600.0)

# %% [markdown]
# # All

# %%
data = np.loadtxt('C:/Research/Nonreciprocity/OrigamiAbaqus/PostProcess/Expr-2-3-adjust/Load1LeftU2-1.txt',skiprows=3)
Load1LeftU2_1 = data[:,1]
T = data[:,0]

fft_result = np.fft.fft(Load1LeftU2_1)
frequencies = np.fft.fftfreq(len(Load1LeftU2_1), (T[-1]-T[0])/len(T))*2*np.pi

plt.figure(figsize=(20,14))

plt.subplot(4,4,1)
plt.plot(T, Load1LeftU2_1)
plt.grid(True)
plt.title('Load1_Left_U2')
plt.ylim((-0.0015, 0.0015))

plt.subplot(4,4,2)
plt.plot(frequencies, abs(fft_result))
plt.grid(True)
plt.xlim(0, 600)
plt.title('Load1_Left_U2_fft')
plt.ylim((0, 0.08))

data = np.loadtxt('C:/Research/Nonreciprocity/OrigamiAbaqus/PostProcess/Expr-2-3-adjust/Load1LeftV2-1.txt',skiprows=3)
Load1LeftV2_1 = data[:,1]
T = data[:,0]

fft_result = np.fft.fft(Load1LeftV2_1)
frequencies = np.fft.fftfreq(len(Load1LeftU2_1), (T[-1]-T[0])/len(T))*2*np.pi

plt.subplot(4,4,3)
plt.plot(T, Load1LeftV2_1)
plt.grid(True)
plt.title('Load1_Left_V2')
plt.ylim((-1.5, 1.5))

plt.subplot(4,4,4)
plt.plot(frequencies, abs(fft_result))
plt.grid(True)
plt.xlim(0, 600)
plt.title('Load1_Left_V2_fft')
plt.ylim((0, 60))

data = np.loadtxt('C:/Research/Nonreciprocity/OrigamiAbaqus/PostProcess/Expr-2-3-adjust/Load1RightU2-1.txt',skiprows=3)
Load1LeftU2_1 = data[:,1]
T = data[:,0]

fft_result = np.fft.fft(Load1LeftU2_1)
frequencies = np.fft.fftfreq(len(Load1LeftU2_1), (T[-1]-T[0])/len(T))*2*np.pi

plt.subplot(4,4,5)
plt.plot(T, Load1LeftU2_1)
plt.grid(True)
plt.title('Load1_Right_U2')
plt.ylim((-0.0015, 0.0015))

plt.subplot(4,4,6)
plt.plot(frequencies, abs(fft_result))
plt.grid(True)
plt.xlim(0, 600)
plt.title('Load1_Right_U2_fft')
plt.ylim((0, 0.08))

data = np.loadtxt('C:/Research/Nonreciprocity/OrigamiAbaqus/PostProcess/Expr-2-3-adjust/Load1RightV2-1.txt',skiprows=3)
Load1LeftV2_1 = data[:,1]
T = data[:,0]

fft_result = np.fft.fft(Load1LeftV2_1)
frequencies = np.fft.fftfreq(len(Load1LeftU2_1), (T[-1]-T[0])/len(T))*2*np.pi

plt.subplot(4,4,7)
plt.plot(T, Load1LeftV2_1)
plt.grid(True)
plt.title('Load1_Right_V2')
plt.ylim((-1.5, 1.5))

plt.subplot(4,4,8)
plt.plot(frequencies, abs(fft_result))
plt.grid(True)
plt.xlim(0, 600)
plt.title('Load1_Right_V2_fft')
plt.ylim((0, 60))

data = np.loadtxt('C:/Research/Nonreciprocity/OrigamiAbaqus/PostProcess/Expr-2-3-adjust/Load2LeftU2-1.txt',skiprows=3)
Load1LeftU2_1 = data[:,1]
T = data[:,0]

fft_result = np.fft.fft(Load1LeftU2_1)
frequencies = np.fft.fftfreq(len(Load1LeftU2_1), (T[-1]-T[0])/len(T))*2*np.pi

plt.subplot(4,4,9)
plt.plot(T, Load1LeftU2_1)
plt.grid(True)
plt.title('Load2_Left_U2')
plt.ylim((-0.0015, 0.0015))


plt.subplot(4,4,10)
plt.plot(frequencies, abs(fft_result))
plt.grid(True)
plt.xlim(0, 600)
plt.title('Load2_Left_U2_fft')
plt.ylim((0, 0.08))

data = np.loadtxt('C:/Research/Nonreciprocity/OrigamiAbaqus/PostProcess/Expr-2-3-adjust/Load2LeftV2-1.txt',skiprows=3)
Load1LeftV2_1 = data[:,1]
T = data[:,0]

fft_result = np.fft.fft(Load1LeftV2_1)
frequencies = np.fft.fftfreq(len(Load1LeftU2_1), (T[-1]-T[0])/len(T))*2*np.pi

plt.subplot(4,4,11)
plt.plot(T, Load1LeftV2_1)
plt.grid(True)
plt.title('Load2_Left_V2')
plt.ylim((-1.5, 1.5))

plt.subplot(4,4,12)
plt.plot(frequencies, abs(fft_result))
plt.grid(True)
plt.xlim(0, 600)
plt.title('Load2_Left_V2_fft')
plt.ylim((0, 60))

data = np.loadtxt('C:/Research/Nonreciprocity/OrigamiAbaqus/PostProcess/Expr-2-3-adjust/Load2RightU2-1.txt',skiprows=3)
Load1LeftU2_1 = data[:,1]
T = data[:,0]

fft_result = np.fft.fft(Load1LeftU2_1)
frequencies = np.fft.fftfreq(len(Load1LeftU2_1), (T[-1]-T[0])/len(T))*2*np.pi

plt.subplot(4,4,13)
plt.plot(T, Load1LeftU2_1)
plt.grid(True)
plt.title('Load2_Right_U2')
plt.ylim((-0.0015, 0.0015))

plt.subplot(4,4,14)
plt.plot(frequencies, abs(fft_result))
plt.grid(True)
plt.xlim(0, 600)
plt.title('Load2_Right_U2_fft')
plt.ylim((0, 0.08))

data = np.loadtxt('C:/Research/Nonreciprocity/OrigamiAbaqus/PostProcess/Expr-2-3-adjust/Load2RightV2-1.txt',skiprows=3)
Load1RightV2_1 = data[:,1]
T = data[:,0]

fft_result = np.fft.fft(Load1RightV2_1)
frequencies = np.fft.fftfreq(len(Load1LeftU2_1), (T[-1]-T[0])/len(T))*2*np.pi

plt.subplot(4,4,15)
plt.plot(T, Load1RightV2_1)
plt.grid(True)
plt.title('Load2_Right_V2')
plt.ylim((-1.5, 1.5))

plt.subplot(4,4,16)
plt.plot(frequencies, abs(fft_result))
plt.grid(True)
plt.xlim(0, 600)
plt.title('Load2_Right_V2_fft')
plt.ylim((0, 60))
# Out:
# (0.0, 60.0)

# %%
plt.figure(figsize=(10,3))
plt.plot(np.linspace(0, 1, 1000), 0.5*np.sin(200*np.linspace(0, 1, 1000)), 'black', label='Load1, Left')
plt.grid(True)
plt.title('Loading Force')
plt.xlabel("Time(s)")
plt.ylabel("Force(N)")
# Out:
# Text(0, 0.5, 'Force(N)')

# %%
# data = np.loadtxt('C:/Research/Nonreciprocity/OrigamiAbaqus/PostProcess/Expr-2-3-adjust/Load1LoadForce.txt',skiprows=3)
# Load1LeftU2_1 = data[:,1]
# T = data[:,0]

# fft_result = np.fft.fft(Load1LeftU2_1)
# frequencies = np.fft.fftfreq(len(Load1LeftU2_1), (T[-1]-T[0])/len(T))*2*np.pi
# plt.figure(figsize=(10,6))

# plt.plot(np.linspace(0, 1, 1000), np.sin(200*np.linspace(0, 1, 1000)), label='Load1, Left')
# plt.grid(True)
# plt.title('Loading Force')
# plt.xlabel("Time(s)")
# plt.ylabel("Force(N)")

# plt.subplot(1,2,2)
# plt.plot(frequencies, abs(fft_result), label='Load1, Left')
# plt.grid(True)
# plt.xlim(0, 600)
# plt.title('Left Loading, U2, fft')
data = np.loadtxt('C:/Research/Nonreciprocity/OrigamiAbaqus/PostProcess/Expr-2-3-adjust/Load1LeftU2-1.txt',skiprows=3)
Load1LeftU2_1 = data[:,1]
T = data[:,0]

fft_result = np.fft.fft(Load1LeftU2_1)
frequencies = np.fft.fftfreq(len(Load1LeftU2_1), (T[-1]-T[0])/len(T))*2*np.pi

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.plot(T, Load1LeftU2_1, 'r')
plt.grid(True)
plt.title('Displacement of Node A')
plt.xlabel('Time(s)')
plt.ylabel('Displacement(m)')
plt.ylim((-0.0005, 0.0005))
data = np.loadtxt('C:/Research/Nonreciprocity/OrigamiAbaqus/PostProcess/Expr-2-3-adjust/Load1RightU2-1.txt',skiprows=3)
Load1LeftU2_1 = data[:,1]
T = data[:,0]
plt.subplot(2,2,2)
plt.plot(T, Load1LeftU2_1, 'b')
plt.grid(True)
plt.title('Displacement of Node B')
plt.xlabel('Time(s)')
plt.ylabel('Displacement(m)')
plt.ylim((-0.0005, 0.0005))
data = np.loadtxt('C:/Research/Nonreciprocity/OrigamiAbaqus/PostProcess/Expr-2-3-adjust/Load1LeftV2-1.txt',skiprows=3)
Load1LeftU2_1 = data[:,1]
T = data[:,0]
plt.subplot(2,2,3)
plt.plot(T, Load1LeftU2_1, 'r')
plt.grid(True)
plt.title('Velocity of Node A')
plt.xlabel('Time(s)')
plt.ylabel('Velocity(m/s)')
plt.ylim((-0.55, 0.55))
data = np.loadtxt('C:/Research/Nonreciprocity/OrigamiAbaqus/PostProcess/Expr-2-3-adjust/Load1RightV2-1.txt',skiprows=3)
Load1LeftU2_1 = data[:,1]
T = data[:,0]
plt.subplot(2,2,4)
plt.plot(T, Load1LeftU2_1, 'b')
plt.grid(True)
plt.title('Velocity of Node B')
plt.xlabel('Time(s)')
plt.ylabel('Velocity(m/s)')
plt.ylim((-0.55, 0.55))
# plt.plot(frequencies, abs(fft_result))
# plt.grid(True)
# plt.xlim(0, 600)
# plt.title('Load1_Left_U2_fft')
# plt.ylim((0, 0.08))
# Out:
# (-0.55, 0.55)

# %%
# data = np.loadtxt('C:/Research/Nonreciprocity/OrigamiAbaqus/PostProcess/Expr-2-3-adjust/Load1LoadForce.txt',skiprows=3)
# Load1LeftU2_1 = data[:,1]
# T = data[:,0]

# fft_result = np.fft.fft(Load1LeftU2_1)
# frequencies = np.fft.fftfreq(len(Load1LeftU2_1), (T[-1]-T[0])/len(T))*2*np.pi
# plt.figure(figsize=(10,6))

# plt.plot(np.linspace(0, 1, 1000), np.sin(200*np.linspace(0, 1, 1000)), label='Load1, Left')
# plt.grid(True)
# plt.title('Loading Force')
# plt.xlabel("Time(s)")
# plt.ylabel("Force(N)")

# plt.subplot(1,2,2)
# plt.plot(frequencies, abs(fft_result), label='Load1, Left')
# plt.grid(True)
# plt.xlim(0, 600)
# plt.title('Left Loading, U2, fft')
data = np.loadtxt('C:/Research/Nonreciprocity/OrigamiAbaqus/PostProcess/Expr-2-3-adjust/Load2LeftU2-1.txt',skiprows=3)
Load1LeftU2_1 = data[:,1]
T = data[:,0]

fft_result = np.fft.fft(Load1LeftU2_1)
frequencies = np.fft.fftfreq(len(Load1LeftU2_1), (T[-1]-T[0])/len(T))*2*np.pi

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
plt.plot(T, Load1LeftU2_1, 'r')
plt.grid(True)
plt.title('Displacement of Node A')
plt.xlabel('Time(s)')
plt.ylabel('Displacement(m)')
plt.ylim((-0.0005, 0.0005))
data = np.loadtxt('C:/Research/Nonreciprocity/OrigamiAbaqus/PostProcess/Expr-2-3-adjust/Load2RightU2-1.txt',skiprows=3)
Load1LeftU2_1 = data[:,1]
T = data[:,0]
plt.subplot(2,2,2)
plt.plot(T, Load1LeftU2_1, 'b')
plt.grid(True)
plt.title('Displacement of Node B')
plt.xlabel('Time(s)')
plt.ylabel('Displacement(m)')
plt.ylim((-0.0005, 0.0005))
data = np.loadtxt('C:/Research/Nonreciprocity/OrigamiAbaqus/PostProcess/Expr-2-3-adjust/Load2LeftV2-1.txt',skiprows=3)
Load1LeftU2_1 = data[:,1]
T = data[:,0]
plt.subplot(2,2,3)
plt.plot(T, Load1LeftU2_1, 'r')
plt.grid(True)
plt.title('Velocity of Node A')
plt.xlabel('Time(s)')
plt.ylabel('Velocity(m/s)')
plt.ylim((-0.55, 0.55))
data = np.loadtxt('C:/Research/Nonreciprocity/OrigamiAbaqus/PostProcess/Expr-2-3-adjust/Load2RightV2-1.txt',skiprows=3)
Load1LeftU2_1 = data[:,1]
T = data[:,0]
plt.subplot(2,2,4)
plt.plot(T, Load1LeftU2_1, 'b')
plt.grid(True)
plt.title('Velocity of Node B')
plt.xlabel('Time(s)')
plt.ylabel('Velocity(m/s)')
plt.ylim((-0.55, 0.55))
# plt.plot(frequencies, abs(fft_result))
# plt.grid(True)
# plt.xlim(0, 600)
# plt.title('Load1_Left_U2_fft')
# plt.ylim((0, 0.08))
# Out:
# (-0.55, 0.55)

# %%
data = np.loadtxt('C:/Research/Nonreciprocity/OrigamiAbaqus/PostProcess/Expr-2-3-adjust/Load1LeftU2-1.txt',skiprows=3)
Load1LeftU2_1 = data[:,1]
T = data[:,0]

fft_result = np.fft.fft(Load1LeftU2_1)
frequencies = np.fft.fftfreq(len(Load1LeftU2_1), (T[-1]-T[0])/len(T))*2*np.pi

plt.figure(figsize=(15,10))

plt.subplot(2,4,1)
plt.plot(T, Load1LeftU2_1, label='Load1, Left')
plt.grid(True)
plt.title('Left Loading, U2')
plt.ylim((-0.0005, 0.0005))

plt.subplot(2,4,2)
plt.plot(frequencies, abs(fft_result), label='Load1, Left')
plt.grid(True)
plt.xlim(0, 600)
plt.title('Left Loading, U2, fft')
plt.ylim((0, 0.03))

data = np.loadtxt('C:/Research/Nonreciprocity/OrigamiAbaqus/PostProcess/Expr-2-3-adjust/Load1LeftV2-1.txt',skiprows=3)
Load1LeftV2_1 = data[:,1]
T = data[:,0]

fft_result = np.fft.fft(Load1LeftV2_1)
frequencies = np.fft.fftfreq(len(Load1LeftU2_1), (T[-1]-T[0])/len(T))*2*np.pi

plt.subplot(2,4,3)
plt.plot(T, Load1LeftV2_1, label='Load1, Left')
plt.grid(True)
plt.title('Left Loading, V2')
plt.ylim((-0.6, 0.6))

plt.subplot(2,4,4)
plt.plot(frequencies, abs(fft_result), label='Load1, Left')
plt.grid(True)
plt.xlim(0, 600)
plt.title('Left Loading, V2_fft')
plt.ylim((0, 30))

data = np.loadtxt('C:/Research/Nonreciprocity/OrigamiAbaqus/PostProcess/Expr-2-3-adjust/Load1RightU2-1.txt',skiprows=3)
Load1LeftU2_1 = data[:,1]
T = data[:,0]

fft_result = np.fft.fft(Load1LeftU2_1)
frequencies = np.fft.fftfreq(len(Load1LeftU2_1), (T[-1]-T[0])/len(T))*2*np.pi

plt.subplot(2,4,1)
plt.plot(T, Load1LeftU2_1, label='Load1, Right')
plt.legend(loc='upper right')

plt.subplot(2,4,2)
plt.plot(frequencies, abs(fft_result), label='Load1, Right')
plt.legend(loc='upper right')

data = np.loadtxt('C:/Research/Nonreciprocity/OrigamiAbaqus/PostProcess/Expr-2-3-adjust/Load1RightV2-1.txt',skiprows=3)
Load1LeftV2_1 = data[:,1]
T = data[:,0]

fft_result = np.fft.fft(Load1LeftV2_1)
frequencies = np.fft.fftfreq(len(Load1LeftU2_1), (T[-1]-T[0])/len(T))*2*np.pi

plt.subplot(2,4,3)
plt.plot(T, Load1LeftV2_1, label='Load1, Right')
plt.legend(loc='upper right')

plt.subplot(2,4,4)
plt.plot(frequencies, abs(fft_result), label='Load2, Right')
plt.grid(True)
plt.legend(loc='upper right')

data = np.loadtxt('C:/Research/Nonreciprocity/OrigamiAbaqus/PostProcess/Expr-2-3-adjust/Load2LeftU2-1.txt',skiprows=3)
Load1LeftU2_1 = data[:,1]
T = data[:,0]

fft_result = np.fft.fft(Load1LeftU2_1)
frequencies = np.fft.fftfreq(len(Load1LeftU2_1), (T[-1]-T[0])/len(T))*2*np.pi

plt.subplot(2,4,5)
plt.title("Right Loading, U2")
plt.plot(T, Load1LeftU2_1, label='Load2, Left')
plt.grid(True)
plt.ylim((-0.0015, 0.0015))


plt.subplot(2,4,6)
plt.plot(frequencies, abs(fft_result), label='Load2, Left')
plt.grid(True)
plt.xlim(0, 600)
plt.title("Right Loading, U2, fft")
plt.ylim((0, 0.1))

data = np.loadtxt('C:/Research/Nonreciprocity/OrigamiAbaqus/PostProcess/Expr-2-3-adjust/Load2LeftV2-1.txt',skiprows=3)
Load1LeftV2_1 = data[:,1]
T = data[:,0]

fft_result = np.fft.fft(Load1LeftV2_1)
frequencies = np.fft.fftfreq(len(Load1LeftU2_1), (T[-1]-T[0])/len(T))*2*np.pi

plt.subplot(2,4,7)
plt.plot(T, Load1LeftV2_1, label='Load2, Left')
plt.grid(True)
plt.title("Right Loading, V2")
plt.ylim((-1.5, 1.5))

plt.subplot(2,4,8)
plt.plot(frequencies, abs(fft_result), label='Load2, Left')
plt.grid(True)
plt.title("Right Loading, V2, fft")
plt.xlim(0, 600)
plt.ylim((0, 60))

data = np.loadtxt('C:/Research/Nonreciprocity/OrigamiAbaqus/PostProcess/Expr-2-3-adjust/Load2RightU2-1.txt',skiprows=3)
Load1LeftU2_1 = data[:,1]
T = data[:,0]

fft_result = np.fft.fft(Load1LeftU2_1)
frequencies = np.fft.fftfreq(len(Load1LeftU2_1), (T[-1]-T[0])/len(T))*2*np.pi

plt.subplot(2,4,5)
plt.plot(T, Load1LeftU2_1, label='Load2, Right')
plt.legend(loc='upper right')

plt.subplot(2,4,6)
plt.plot(frequencies, abs(fft_result), label='Load2, Right')
plt.legend(loc='upper right')

data = np.loadtxt('C:/Research/Nonreciprocity/OrigamiAbaqus/PostProcess/Expr-2-3-adjust/Load2RightV2-1.txt',skiprows=3)
Load1LeftV2_1 = data[:,1]
T = data[:,0]

fft_result = np.fft.fft(Load1LeftV2_1)
frequencies = np.fft.fftfreq(len(Load1LeftU2_1), (T[-1]-T[0])/len(T))*2*np.pi

plt.subplot(2,4,7)
plt.plot(T, Load1LeftV2_1, label='Load2, Right')
plt.legend(loc='upper right')

plt.subplot(2,4,8)
plt.plot(frequencies, abs(fft_result), label='Load2, Right')
plt.legend(loc='upper right')
